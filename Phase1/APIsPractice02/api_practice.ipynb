# %% [markdown]
# # APIs and Python

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ### Learning Goals:
#
#   - Identify and discuss APIs
#   - Discuss and explain different request (GET, POST, PUT, DELETE) and CRUD operations
#   - Explore the attributes of a response object
#   - Check the status of a request and interpret status codes
#   - Access data from an API using the requests library
#   - Create a pandas dataframe from the data returned from an API and visualize the data

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information through their API.
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? Every API is different! There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it
#!pip install requests

# %% [markdown]
# ### Types of requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Request Class and Attributes

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"11658711808","type":"CreateEvent","actor":{"id":47148648,"login":"svc-software-factory","display_login":"svc-software-factory","gravatar_id":"","url":"https://api.github.com/users/svc-software-factory","avatar_url":"https://avatars.githubusercontent.com/u/47148648?"},"repo":{"id":197735754,"name":"adeo-gitlab/sync-github-gitlab-27","url":"https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-27"},"payload":{"ref":"2020-03-02_22-10-05_544_scenario1","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-03-02T22:10:16Z","org":{"id":52697831,"login":"adeo-gitlab","gravatar_id":"","url":"https://api.github.com/orgs/adeo-gitlab","avatar_url":"https://avatars.githubusercontent.com/u/52697831?"}},{"id":"11658711803","type":"PushEvent","actor":{"id":54567334,"login":"lrondenet","display_login":"lrondenet","gravatar_id":"","url":"https://api.github.com/users/lrondenet","avatar_url":"https://avatars.githubusercontent.com/u/54567334?"},"repo":{"id":241203180,"name":"lrondenet/StudyGroup","url":"https://api.github.com/repos/lrondenet/StudyGroup"},"payload":{"push_id":4708104192,"size":2,"distinct_size":0,"ref":"refs/heads/master","head":"77bdc233b5f5f0d2eddc06a08e5a309ea7fae636","before":"584b8b63c8546d601bbdc27b55999b15a811b850","commits":[{"sha":"cf22ef6db370485f652d3c81c3ad5489c2362fa6","author":{"email":"lrondenet1@mail.csuchico.edu","name":"lrondenet"},"message":"adding new files","distinct":false,"url":"https://api.github.com/repos/lrondenet/StudyGroup/commits/cf22ef6db370485f652d3c81c3ad5489c2362fa6"},{"sha":"77bdc233b5f5f0d2eddc06a08e5a309ea7fae636","author":{"email":"lrondenet1@mail.csuchico.edu","name":"lrondenet"},"message":"Merge branch \'master\' of https://github.com/lrondenet/StudyGroup\\n\\nadding new files for course_schedule","distinct":false,"url":"https://api.github.com/repos/lrondenet/StudyGroup/commits/77bdc233b5f5f0d2eddc06a08e5a309ea7fae636"}]},"public":true,"created_at":"2020-03-02T22:10:16Z"},{"id":"11658711799","type":"PushEvent","actor":{"id":43799723,"login":"TerryThreatt","display_login":"TerryThreatt","gravatar_id":"","url":"https://api.github.com/users/TerryThreatt","avatar_url":"https://avatars.githubusercontent.com/u/43799723?"},"repo":{"id":244476462,"name":"TerryThreatt/ruby-advanced-class-methods-lab-onl01-seng-pt-021020","url":"https://api.github.com/repos/TerryThreatt/ruby-advanced-class-methods-lab-onl01-seng-pt-021020"},"payload":{"push_id":4708104200,"size":1,"distinct_size":1,"ref":"refs/heads/wip","head":"d05f645b20f0ead2ce2264e31876f4a188d7f281","before":"63f12b9db6a27f914ae0db0acb9cf00d70ea1332","commits":[{"sha":"d05f645b20f0ead2ce2264e31876f4a188d7f281","author":{"email":"terry.threatt@gmail.com","name":"Terry Threatt"},"message":"Automatically backed up by Learn","distinct":true,"url":"https://api.github.com/repos/TerryThreatt/ruby-advanced-class-methods-lab-onl01-seng-pt-021020/commits/d05f645b20f0ead2ce2264e31876f4a188d7f281"}]},"public":true,"created_at":"2020-03-02T22:10:16Z"},{"id":"11658711801","type":"WatchEvent","actor":{"id":55340228,"login":"JY-Sun-K","display_login":"JY-Sun-K","gravatar_id":"","url":"https://api.github.com/users/JY-Sun-K","avatar_url":"https://avatars.githubusercontent.com/u/55340228?"},"repo":{"id":115414519,"name":"lenve/VBlog","url":"https://api.github.com/repos/lenve/VBlog"},"payload":{"action":"started"},"public":true,"created_at":"2020-03-02T22:10:16Z"},{"id":"11658711791","type":"PushEvent","actor":{"id":31894641,"login":"Davyd11","display_login":"Davyd11","gravatar_id":"","url":"https://api.github.com/users/Davyd11","avatar_url":"https://avatars.githubusercontent.com/u/31894641?"},"repo":{"id":241882529,"name":"Davyd11/ft_printf","url":"https://api.github.com/repos/Davyd11/ft_printf"},"payload":{"push_id":4708104181,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"ad6bb3ca0c9ad4400ce8be19676cc9aaa22fd89f","before":"b8d7eb5d059bd06eca874effb6cccdab7b98d43f","commits ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Mon, 02 Mar 2020 22:15:17 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Status': '200 OK', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '41', 'X-RateLimit-Reset': '1583188740', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"f40a6209c645b8426888f9cc0f98913b"', 'Last-Modified': 'Mon, 02 Mar 2020 22:10:16 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': 'E0F1:376B:1320806:28B5664:5E5D8574'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '11658711808',
#   'type': 'CreateEvent',
#   'actor': {'id': 47148648,
#    'login': 'svc-software-factory',
#    'display_login': 'svc-software-factory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svc-software-factory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47148648?'},
#   'repo': {'id': 197735754,
#    'name': 'adeo-gitlab/sync-github-gitlab-27',
#    'url': 'https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-27'},
#   'payload': {'ref': '2020-03-02_22-10-05_544_scenario1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z',
#   'org': {'id': 52697831,
#    'login': 'adeo-gitlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adeo-gitlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52697831?'}},
#  {'id': '11658711803',
#   'type': 'PushEvent',
#   'actor': {'id': 54567334,
#    'login': 'lrondenet',
#    'display_login': 'lrondenet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lrondenet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54567334?'},
#   'repo': {'id': 241203180,
#    'name': 'lrondenet/StudyGroup',
#    'url': 'https://api.github.com/repos/lrondenet/StudyGroup'},
#   'payload': {'push_id': 4708104192,
#    'size': 2,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '77bdc233b5f5f0d2eddc06a08e5a309ea7fae636',
#    'before': '584b8b63c8546d601bbdc27b55999b15a811b850',
#    'commits': [{'sha': 'cf22ef6db370485f652d3c81c3ad5489c2362fa6',
#      'author': {'email': 'lrondenet1@mail.csuchico.edu', 'name': 'lrondenet'},
#      'message': 'adding new files',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/lrondenet/StudyGroup/commits/cf22ef6db370485f652d3c81c3ad5489c2362fa6'},
#     {'sha': '77bdc233b5f5f0d2eddc06a08e5a309ea7fae636',
#      'author': {'email': 'lrondenet1@mail.csuchico.edu', 'name': 'lrondenet'},
#      'message': "Merge branch 'master' of https://github.com/lrondenet/StudyGroup\n\nadding new files for course_schedule",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/lrondenet/StudyGroup/commits/77bdc233b5f5f0d2eddc06a08e5a309ea7fae636'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711799',
#   'type': 'PushEvent',
#   'actor': {'id': 43799723,
#    'login': 'TerryThreatt',
#    'display_login': 'TerryThreatt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TerryThreatt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43799723?'},
#   'repo': {'id': 244476462,
#    'name': 'TerryThreatt/ruby-advanced-class-methods-lab-onl01-seng-pt-021020',
#    'url': 'https://api.github.com/repos/TerryThreatt/ruby-advanced-class-methods-lab-onl01-seng-pt-021020'},
#   'payload': {'push_id': 4708104200,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': 'd05f645b20f0ead2ce2264e31876f4a188d7f281',
#    'before': '63f12b9db6a27f914ae0db0acb9cf00d70ea1332',
#    'commits': [{'sha': 'd05f645b20f0ead2ce2264e31876f4a188d7f281',
#      'author': {'email': 'terry.threatt@gmail.com', 'name': 'Terry Threatt'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TerryThreatt/ruby-advanced-class-methods-lab-onl01-seng-pt-021020/commits/d05f645b20f0ead2ce2264e31876f4a188d7f281'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711801',
#   'type': 'WatchEvent',
#   'actor': {'id': 55340228,
#    'login': 'JY-Sun-K',
#    'display_login': 'JY-Sun-K',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JY-Sun-K',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55340228?'},
#   'repo': {'id': 115414519,
#    'name': 'lenve/VBlog',
#    'url': 'https://api.github.com/repos/lenve/VBlog'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711791',
#   'type': 'PushEvent',
#   'actor': {'id': 31894641,
#    'login': 'Davyd11',
#    'display_login': 'Davyd11',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Davyd11',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31894641?'},
#   'repo': {'id': 241882529,
#    'name': 'Davyd11/ft_printf',
#    'url': 'https://api.github.com/repos/Davyd11/ft_printf'},
#   'payload': {'push_id': 4708104181,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ad6bb3ca0c9ad4400ce8be19676cc9aaa22fd89f',
#    'before': 'b8d7eb5d059bd06eca874effb6cccdab7b98d43f',
#    'commits': [{'sha': 'ad6bb3ca0c9ad4400ce8be19676cc9aaa22fd89f',
#      'author': {'email': 'david.puente.r@gmail.com', 'name': 'David'},
#      'message': 'hexadecimals done but without tests',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Davyd11/ft_printf/commits/ad6bb3ca0c9ad4400ce8be19676cc9aaa22fd89f'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711790',
#   'type': 'CreateEvent',
#   'actor': {'id': 4822,
#    'login': 'esjewett',
#    'display_login': 'esjewett',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/esjewett',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4822?'},
#   'repo': {'id': 210379735,
#    'name': 'MindsetConsulting/MindsetAppAnalyzerFree',
#    'url': 'https://api.github.com/repos/MindsetConsulting/MindsetAppAnalyzerFree'},
#   'payload': {'ref': 'linting-setup',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Mindset App Analyzer for SAP Fiori Free Download',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z',
#   'org': {'id': 8583610,
#    'login': 'MindsetConsulting',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/MindsetConsulting',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8583610?'}},
#  {'id': '11658711784',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 9107200,
#    'login': 'Crown421',
#    'display_login': 'Crown421',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Crown421',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9107200?'},
#   'repo': {'id': 17227100,
#    'name': 'JuliaMath/IntelVectorMath.jl',
#    'url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/comments/386681402',
#     'pull_request_review_id': 367566277,
#     'id': 386681402,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM4NjY4MTQwMg==',
#     'diff_hunk': '@@ -97,14 +87,14 @@ function def_binary_op(tin, tout, jlname, jlname!, mklname, broadcast)\n         $(isempty(exports) ? nothing : Expr(:export, exports...))\n         function ($jlname!)(out::Array{$tout,N}, A::Array{$tin,N}, B::Array{$tin,N}) where {N}\n             size(out) == size(A) == size(B) || $(broadcast ? :(return broadcast!($jlname, out, A, B)) : :(throw(DimensionMismatch())))',
#     'path': 'src/setup.jl',
#     'position': 83,
#     'original_position': 83,
#     'commit_id': '34781b92cebba6ce096a224a511a6d804219b50d',
#     'original_commit_id': '34781b92cebba6ce096a224a511a6d804219b50d',
#     'user': {'login': 'Crown421',
#      'id': 9107200,
#      'node_id': 'MDQ6VXNlcjkxMDcyMDA=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/9107200?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Crown421',
#      'html_url': 'https://github.com/Crown421',
#      'followers_url': 'https://api.github.com/users/Crown421/followers',
#      'following_url': 'https://api.github.com/users/Crown421/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Crown421/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Crown421/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Crown421/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Crown421/orgs',
#      'repos_url': 'https://api.github.com/users/Crown421/repos',
#      'events_url': 'https://api.github.com/users/Crown421/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Crown421/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'More legacy code, maybe something that was a thing before Julia 0.7. I will have a look',
#     'created_at': '2020-03-02T22:10:15Z',
#     'updated_at': '2020-03-02T22:10:16Z',
#     'html_url': 'https://github.com/JuliaMath/IntelVectorMath.jl/pull/39#discussion_r386681402',
#     'pull_request_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/39',
#     'author_association': 'COLLABORATOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/comments/386681402'},
#      'html': {'href': 'https://github.com/JuliaMath/IntelVectorMath.jl/pull/39#discussion_r386681402'},
#      'pull_request': {'href': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/39'}},
#     'in_reply_to_id': 386679148},
#    'pull_request': {'url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/39',
#     'id': 381680984,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgxNjgwOTg0',
#     'html_url': 'https://github.com/JuliaMath/IntelVectorMath.jl/pull/39',
#     'diff_url': 'https://github.com/JuliaMath/IntelVectorMath.jl/pull/39.diff',
#     'patch_url': 'https://github.com/JuliaMath/IntelVectorMath.jl/pull/39.patch',
#     'issue_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/issues/39',
#     'number': 39,
#     'state': 'open',
#     'locked': False,
#     'title': 'Adding MKL_jll artifact',
#     'user': {'login': 'Crown421',
#      'id': 9107200,
#      'node_id': 'MDQ6VXNlcjkxMDcyMDA=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/9107200?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Crown421',
#      'html_url': 'https://github.com/Crown421',
#      'followers_url': 'https://api.github.com/users/Crown421/followers',
#      'following_url': 'https://api.github.com/users/Crown421/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Crown421/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Crown421/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Crown421/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Crown421/orgs',
#      'repos_url': 'https://api.github.com/users/Crown421/repos',
#      'events_url': 'https://api.github.com/users/Crown421/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Crown421/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'This pull request add dependence on the `MKL_jll` artifact, and changes all references from the `libmkl_vml_avx` libraries to the `libmkl_rt` library. \r\nThis has the advantage that MKL chooses the correct instruction set on runtime, making this package and its precompile cache hardware independent. \r\n(Thanks @KristofferC !)\r\n\r\nParadiso.jl currently checks for the existence of a local install of MKL and uses it if one is found. However, given that `MKL_jll` is now an explicit dependency, it will installed regardless. Given this, it might as well be used. \r\nThis will be revisited if it becomes useful to enable user choice for a specific version of MKL via a manual external install. ',
#     'created_at': '2020-02-29T01:58:35Z',
#     'updated_at': '2020-03-02T22:10:16Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '7ea7a88fae6e88b715cea23707084efdec5ebb1b',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/39/commits',
#     'review_comments_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/39/comments',
#     'review_comment_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/issues/39/comments',
#     'statuses_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/statuses/34781b92cebba6ce096a224a511a6d804219b50d',
#     'head': {'label': 'JuliaMath:artifact',
#      'ref': 'artifact',
#      'sha': '34781b92cebba6ce096a224a511a6d804219b50d',
#      'user': {'login': 'JuliaMath',
#       'id': 19329613,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE5MzI5NjEz',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/19329613?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/JuliaMath',
#       'html_url': 'https://github.com/JuliaMath',
#       'followers_url': 'https://api.github.com/users/JuliaMath/followers',
#       'following_url': 'https://api.github.com/users/JuliaMath/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/JuliaMath/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/JuliaMath/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/JuliaMath/subscriptions',
#       'organizations_url': 'https://api.github.com/users/JuliaMath/orgs',
#       'repos_url': 'https://api.github.com/users/JuliaMath/repos',
#       'events_url': 'https://api.github.com/users/JuliaMath/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/JuliaMath/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 17227100,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzIyNzEwMA==',
#       'name': 'IntelVectorMath.jl',
#       'full_name': 'JuliaMath/IntelVectorMath.jl',
#       'private': False,
#       'owner': {'login': 'JuliaMath',
#        'id': 19329613,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE5MzI5NjEz',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/19329613?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/JuliaMath',
#        'html_url': 'https://github.com/JuliaMath',
#        'followers_url': 'https://api.github.com/users/JuliaMath/followers',
#        'following_url': 'https://api.github.com/users/JuliaMath/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/JuliaMath/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/JuliaMath/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/JuliaMath/subscriptions',
#        'organizations_url': 'https://api.github.com/users/JuliaMath/orgs',
#        'repos_url': 'https://api.github.com/users/JuliaMath/repos',
#        'events_url': 'https://api.github.com/users/JuliaMath/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/JuliaMath/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/JuliaMath/IntelVectorMath.jl',
#       'description': 'Julia bindings for the Intel Vector Math Library',
#       'fork': False,
#       'url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl',
#       'forks_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/forks',
#       'keys_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/teams',
#       'hooks_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/hooks',
#       'issue_events_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/events',
#       'assignees_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/tags',
#       'blobs_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/languages',
#       'stargazers_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/stargazers',
#       'contributors_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/contributors',
#       'subscribers_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/subscribers',
#       'subscription_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/subscription',
#       'commits_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/merges',
#       'archive_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/downloads',
#       'issues_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/deployments',
#       'created_at': '2014-02-26T21:58:19Z',
#       'updated_at': '2020-03-01T15:35:10Z',
#       'pushed_at': '2020-03-02T00:16:08Z',
#       'git_url': 'git://github.com/JuliaMath/IntelVectorMath.jl.git',
#       'ssh_url': 'git@github.com:JuliaMath/IntelVectorMath.jl.git',
#       'clone_url': 'https://github.com/JuliaMath/IntelVectorMath.jl.git',
#       'svn_url': 'https://github.com/JuliaMath/IntelVectorMath.jl',
#       'homepage': None,
#       'size': 15644,
#       'stargazers_count': 43,
#       'watchers_count': 43,
#       'language': 'Julia',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 15,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 8,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 15,
#       'open_issues': 8,
#       'watchers': 43,
#       'default_branch': 'master'}},
#     'base': {'label': 'JuliaMath:master',
#      'ref': 'master',
#      'sha': '995138db06dbd2e808017629ddaab74740eff0b6',
#      'user': {'login': 'JuliaMath',
#       'id': 19329613,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE5MzI5NjEz',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/19329613?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/JuliaMath',
#       'html_url': 'https://github.com/JuliaMath',
#       'followers_url': 'https://api.github.com/users/JuliaMath/followers',
#       'following_url': 'https://api.github.com/users/JuliaMath/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/JuliaMath/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/JuliaMath/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/JuliaMath/subscriptions',
#       'organizations_url': 'https://api.github.com/users/JuliaMath/orgs',
#       'repos_url': 'https://api.github.com/users/JuliaMath/repos',
#       'events_url': 'https://api.github.com/users/JuliaMath/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/JuliaMath/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 17227100,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzIyNzEwMA==',
#       'name': 'IntelVectorMath.jl',
#       'full_name': 'JuliaMath/IntelVectorMath.jl',
#       'private': False,
#       'owner': {'login': 'JuliaMath',
#        'id': 19329613,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE5MzI5NjEz',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/19329613?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/JuliaMath',
#        'html_url': 'https://github.com/JuliaMath',
#        'followers_url': 'https://api.github.com/users/JuliaMath/followers',
#        'following_url': 'https://api.github.com/users/JuliaMath/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/JuliaMath/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/JuliaMath/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/JuliaMath/subscriptions',
#        'organizations_url': 'https://api.github.com/users/JuliaMath/orgs',
#        'repos_url': 'https://api.github.com/users/JuliaMath/repos',
#        'events_url': 'https://api.github.com/users/JuliaMath/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/JuliaMath/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/JuliaMath/IntelVectorMath.jl',
#       'description': 'Julia bindings for the Intel Vector Math Library',
#       'fork': False,
#       'url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl',
#       'forks_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/forks',
#       'keys_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/teams',
#       'hooks_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/hooks',
#       'issue_events_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/events',
#       'assignees_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/tags',
#       'blobs_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/languages',
#       'stargazers_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/stargazers',
#       'contributors_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/contributors',
#       'subscribers_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/subscribers',
#       'subscription_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/subscription',
#       'commits_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/merges',
#       'archive_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/downloads',
#       'issues_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/deployments',
#       'created_at': '2014-02-26T21:58:19Z',
#       'updated_at': '2020-03-01T15:35:10Z',
#       'pushed_at': '2020-03-02T00:16:08Z',
#       'git_url': 'git://github.com/JuliaMath/IntelVectorMath.jl.git',
#       'ssh_url': 'git@github.com:JuliaMath/IntelVectorMath.jl.git',
#       'clone_url': 'https://github.com/JuliaMath/IntelVectorMath.jl.git',
#       'svn_url': 'https://github.com/JuliaMath/IntelVectorMath.jl',
#       'homepage': None,
#       'size': 15644,
#       'stargazers_count': 43,
#       'watchers_count': 43,
#       'language': 'Julia',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 15,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 8,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 15,
#       'open_issues': 8,
#       'watchers': 43,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/39'},
#      'html': {'href': 'https://github.com/JuliaMath/IntelVectorMath.jl/pull/39'},
#      'issue': {'href': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/issues/39'},
#      'comments': {'href': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/issues/39/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/39/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/pulls/39/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/JuliaMath/IntelVectorMath.jl/statuses/34781b92cebba6ce096a224a511a6d804219b50d'}},
#     'author_association': 'COLLABORATOR'}},
#   'public': True,
#   'created_at': '2020-03-02T22:10:15Z',
#   'org': {'id': 19329613,
#    'login': 'JuliaMath',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/JuliaMath',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19329613?'}},
#  {'id': '11658711771',
#   'type': 'PushEvent',
#   'actor': {'id': 8964223,
#    'login': 'labryga',
#    'display_login': 'labryga',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/labryga',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8964223?'},
#   'repo': {'id': 154050328,
#    'name': 'labryga/siabim',
#    'url': 'https://api.github.com/repos/labryga/siabim'},
#   'payload': {'push_id': 4708104164,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cb2569ddb267b48a2f09e4e8b42edd9b68e013b4',
#    'before': '2b3b1987fc38764ab8170e64f9eda58eebbc3cff',
#    'commits': [{'sha': 'cb2569ddb267b48a2f09e4e8b42edd9b68e013b4',
#      'author': {'email': 'martin@labryga.ch', 'name': 'Martin Labryga'},
#      'message': 'homepage adjusted',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/labryga/siabim/commits/cb2569ddb267b48a2f09e4e8b42edd9b68e013b4'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711782',
#   'type': 'PushEvent',
#   'actor': {'id': 12503689,
#    'login': 'valff',
#    'display_login': 'valff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/valff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12503689?'},
#   'repo': {'id': 158371221,
#    'name': 'drone-os/drone-stm32-map',
#    'url': 'https://api.github.com/repos/drone-os/drone-stm32-map'},
#   'payload': {'push_id': 4708104186,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cf38197aaf5404d6432cc8ab10694d6c7ba2a104',
#    'before': '7140bbca90f7b86bb93ed5450ab72201b966aa82',
#    'commits': [{'sha': 'cf38197aaf5404d6432cc8ab10694d6c7ba2a104',
#      'author': {'email': 'valentine.valyaeff@gmail.com',
#       'name': 'Valentine Valyaeff'},
#      'message': 'Use `drone_svd::Config`',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/drone-os/drone-stm32-map/commits/cf38197aaf5404d6432cc8ab10694d6c7ba2a104'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z',
#   'org': {'id': 32068398,
#    'login': 'drone-os',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/drone-os',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32068398?'}},
#  {'id': '11658711755',
#   'type': 'PushEvent',
#   'actor': {'id': 17598973,
#    'login': 'Rdwburns',
#    'display_login': 'Rdwburns',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rdwburns',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17598973?'},
#   'repo': {'id': 244476830,
#    'name': 'Rdwburns/free-for-marketing',
#    'url': 'https://api.github.com/repos/Rdwburns/free-for-marketing'},
#   'payload': {'push_id': 4708104173,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fdd0a04bc6836f4bd6349e701551dcd32c93c6c5',
#    'before': '6d4a1f860a8a3b96e59c0bad764d8b8270afba11',
#    'commits': [{'sha': 'fdd0a04bc6836f4bd6349e701551dcd32c93c6c5',
#      'author': {'email': 'rdwburns@gmail.com', 'name': 'Rdwburns'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Rdwburns/free-for-marketing/commits/fdd0a04bc6836f4bd6349e701551dcd32c93c6c5'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711752',
#   'type': 'PushEvent',
#   'actor': {'id': 43733305,
#    'login': 'yanonono',
#    'display_login': 'yanonono',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yanonono',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43733305?'},
#   'repo': {'id': 183440182,
#    'name': 'yanonono/booth-update',
#    'url': 'https://api.github.com/repos/yanonono/booth-update'},
#   'payload': {'push_id': 4708104170,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6cf5af5affd789480063f0b33d906af3cdb85cd1',
#    'before': '901ea148aa89a12464d01e22bb2944cf1ce03b26',
#    'commits': [{'sha': '6cf5af5affd789480063f0b33d906af3cdb85cd1',
#      'author': {'email': 'yano.nono.0701+booth-github@gmail.com',
#       'name': 'yano.nono'},
#      'message': 'updated at: 2020-03-02 22:10, IMR-205 CERCATORE - IMR-Industry booth直営店 - BOOTH',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yanonono/booth-update/commits/6cf5af5affd789480063f0b33d906af3cdb85cd1'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711748',
#   'type': 'CreateEvent',
#   'actor': {'id': 22098819,
#    'login': 'tantug',
#    'display_login': 'tantug',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tantug',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22098819?'},
#   'repo': {'id': 244486277,
#    'name': 'tantug/api_test',
#    'url': 'https://api.github.com/repos/tantug/api_test'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711750',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 213467,
#    'login': 'finger563',
#    'display_login': 'finger563',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/finger563',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/213467?'},
#   'repo': {'id': 192611562,
#    'name': 'Max-Mobility/permobil-client',
#    'url': 'https://api.github.com/repos/Max-Mobility/permobil-client'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Max-Mobility/permobil-client/issues/779',
#     'repository_url': 'https://api.github.com/repos/Max-Mobility/permobil-client',
#     'labels_url': 'https://api.github.com/repos/Max-Mobility/permobil-client/issues/779/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Max-Mobility/permobil-client/issues/779/comments',
#     'events_url': 'https://api.github.com/repos/Max-Mobility/permobil-client/issues/779/events',
#     'html_url': 'https://github.com/Max-Mobility/permobil-client/issues/779',
#     'id': 574195910,
#     'node_id': 'MDU6SXNzdWU1NzQxOTU5MTA=',
#     'number': 779,
#     'title': 'Enhancement: remove date-fns dependency from Wear Apps',
#     'user': {'login': 'bradmartin',
#      'id': 6006148,
#      'node_id': 'MDQ6VXNlcjYwMDYxNDg=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/6006148?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bradmartin',
#      'html_url': 'https://github.com/bradmartin',
#      'followers_url': 'https://api.github.com/users/bradmartin/followers',
#      'following_url': 'https://api.github.com/users/bradmartin/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bradmartin/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bradmartin/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bradmartin/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bradmartin/orgs',
#      'repos_url': 'https://api.github.com/users/bradmartin/repos',
#      'events_url': 'https://api.github.com/users/bradmartin/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bradmartin/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1412331033,
#       'node_id': 'MDU6TGFiZWwxNDEyMzMxMDMz',
#       'url': 'https://api.github.com/repos/Max-Mobility/permobil-client/labels/enhancement',
#       'name': 'enhancement',
#       'color': 'a2eeef',
#       'default': True,
#       'description': 'New feature or request'},
#      {'id': 1416872564,
#       'node_id': 'MDU6TGFiZWwxNDE2ODcyNTY0',
#       'url': 'https://api.github.com/repos/Max-Mobility/permobil-client/labels/pushtracker-wear',
#       'name': 'pushtracker-wear',
#       'color': '0082ad',
#       'default': False,
#       'description': ''},
#      {'id': 1416873192,
#       'node_id': 'MDU6TGFiZWwxNDE2ODczMTky',
#       'url': 'https://api.github.com/repos/Max-Mobility/permobil-client/labels/smartdrive-wear',
#       'name': 'smartdrive-wear',
#       'color': '8e53e8',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'bradmartin',
#      'id': 6006148,
#      'node_id': 'MDQ6VXNlcjYwMDYxNDg=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/6006148?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bradmartin',
#      'html_url': 'https://github.com/bradmartin',
#      'followers_url': 'https://api.github.com/users/bradmartin/followers',
#      'following_url': 'https://api.github.com/users/bradmartin/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bradmartin/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bradmartin/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bradmartin/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bradmartin/orgs',
#      'repos_url': 'https://api.github.com/users/bradmartin/repos',
#      'events_url': 'https://api.github.com/users/bradmartin/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bradmartin/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'bradmartin',
#       'id': 6006148,
#       'node_id': 'MDQ6VXNlcjYwMDYxNDg=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/6006148?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/bradmartin',
#       'html_url': 'https://github.com/bradmartin',
#       'followers_url': 'https://api.github.com/users/bradmartin/followers',
#       'following_url': 'https://api.github.com/users/bradmartin/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/bradmartin/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/bradmartin/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/bradmartin/subscriptions',
#       'organizations_url': 'https://api.github.com/users/bradmartin/orgs',
#       'repos_url': 'https://api.github.com/users/bradmartin/repos',
#       'events_url': 'https://api.github.com/users/bradmartin/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/bradmartin/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-03-02T19:30:26Z',
#     'updated_at': '2020-03-02T22:10:16Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'body': 'To reduce overall bundle and dependency list, we can remove `date-fns` and use plain JS or Java we have already written in the watchface for formatting and date manipulation work.'},
#    'comment': {'url': 'https://api.github.com/repos/Max-Mobility/permobil-client/issues/comments/593649277',
#     'html_url': 'https://github.com/Max-Mobility/permobil-client/issues/779#issuecomment-593649277',
#     'issue_url': 'https://api.github.com/repos/Max-Mobility/permobil-client/issues/779',
#     'id': 593649277,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5MzY0OTI3Nw==',
#     'user': {'login': 'finger563',
#      'id': 213467,
#      'node_id': 'MDQ6VXNlcjIxMzQ2Nw==',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/213467?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/finger563',
#      'html_url': 'https://github.com/finger563',
#      'followers_url': 'https://api.github.com/users/finger563/followers',
#      'following_url': 'https://api.github.com/users/finger563/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/finger563/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/finger563/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/finger563/subscriptions',
#      'organizations_url': 'https://api.github.com/users/finger563/orgs',
#      'repos_url': 'https://api.github.com/users/finger563/repos',
#      'events_url': 'https://api.github.com/users/finger563/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/finger563/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-03-02T22:10:16Z',
#     'updated_at': '2020-03-02T22:10:16Z',
#     'author_association': 'MEMBER',
#     'body': 'The functions we use are:\r\n```\r\nclosestIndexTo\r\neachDay\r\nformat\r\nisSameDay\r\nisToday\r\nsubDays\r\n```\r\n\r\n`format` can probably be replaced by `SimpleDateFormat` which means we can stop importing all the languages and can just use `SimpleDateFormat::format(...)` which automatically uses the device language (as we want to).'}},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z',
#   'org': {'id': 32078816,
#    'login': 'Max-Mobility',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Max-Mobility',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32078816?'}},
#  {'id': '11658711727',
#   'type': 'PushEvent',
#   'actor': {'id': 354652,
#    'login': 'DevanB',
#    'display_login': 'DevanB',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DevanB',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/354652?'},
#   'repo': {'id': 206982775,
#    'name': 'DevanB/xstate-examples',
#    'url': 'https://api.github.com/repos/DevanB/xstate-examples'},
#   'payload': {'push_id': 4708104168,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '5041b670663c5a282decd33f7121828bea8cf120',
#    'before': '5de949bf35eecddb1fbc6011c7220e0cc5c21b18',
#    'commits': [{'sha': '5b585d798ff0a18f5a74c6e37ac0aafc6d4480c6',
#      'author': {'email': '27856297+dependabot-preview[bot]@users.noreply.github.com',
#       'name': 'dependabot-preview[bot]'},
#      'message': 'Bump @rollup/plugin-node-resolve in /trivia-game-svelte\n\nBumps [@rollup/plugin-node-resolve](https://github.com/rollup/plugins) from 7.0.0 to 7.1.1.\n- [Release notes](https://github.com/rollup/plugins/releases)\n- [Commits](https://github.com/rollup/plugins/compare/node-resolve-v7.0.0...node-resolve-v7.1.1)\n\nSigned-off-by: dependabot-preview[bot] <support@dependabot.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DevanB/xstate-examples/commits/5b585d798ff0a18f5a74c6e37ac0aafc6d4480c6'},
#     {'sha': '5041b670663c5a282decd33f7121828bea8cf120',
#      'author': {'email': 'devan@devanb.us', 'name': 'Devan'},
#      'message': 'Merge pull request #183 from DevanB/dependabot/npm_and_yarn/trivia-game-svelte/rollup/plugin-node-resolve-7.1.1\n\nBump @rollup/plugin-node-resolve from 7.0.0 to 7.1.1 in /trivia-game-svelte',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DevanB/xstate-examples/commits/5041b670663c5a282decd33f7121828bea8cf120'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711729',
#   'type': 'DeleteEvent',
#   'actor': {'id': 354652,
#    'login': 'DevanB',
#    'display_login': 'DevanB',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DevanB',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/354652?'},
#   'repo': {'id': 206982775,
#    'name': 'DevanB/xstate-examples',
#    'url': 'https://api.github.com/repos/DevanB/xstate-examples'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/trivia-game-svelte/rollup/plugin-node-resolve-7.1.1',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711719',
#   'type': 'PushEvent',
#   'actor': {'id': 61658808,
#    'login': 'blazejwrobel98',
#    'display_login': 'blazejwrobel98',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/blazejwrobel98',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61658808?'},
#   'repo': {'id': 244201470,
#    'name': 'blazejwrobel98/Emerytura14',
#    'url': 'https://api.github.com/repos/blazejwrobel98/Emerytura14'},
#   'payload': {'push_id': 4708104162,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'dc8201a4460fc03309b729eafc40235a78475d7b',
#    'before': '45fcad1636d1e02c4f2e6ff80c5f360696034d3a',
#    'commits': [{'sha': 'dc8201a4460fc03309b729eafc40235a78475d7b',
#      'author': {'email': 'blazej.wrobel@microsoft.wsei.edu.pl',
#       'name': 'Błażej Wróbel'},
#      'message': '.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/blazejwrobel98/Emerytura14/commits/dc8201a4460fc03309b729eafc40235a78475d7b'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711721',
#   'type': 'PushEvent',
#   'actor': {'id': 7042,
#    'login': 'petertodd',
#    'display_login': 'petertodd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/petertodd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7042?'},
#   'repo': {'id': 164409575,
#    'name': 'opentimestamps/nist-inject',
#    'url': 'https://api.github.com/repos/opentimestamps/nist-inject'},
#   'payload': {'push_id': 4708104166,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '02005b93269c364cb5df024a9c3ebad74c8c9c14',
#    'before': 'b800e308254282d8432ec242cbee807496f95f21',
#    'commits': [{'sha': '02005b93269c364cb5df024a9c3ebad74c8c9c14',
#      'author': {'email': 'nist-inject@opentimestamps.org',
#       'name': 'nist-injector-bot'},
#      'message': '.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/opentimestamps/nist-inject/commits/02005b93269c364cb5df024a9c3ebad74c8c9c14'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z',
#   'org': {'id': 2550462,
#    'login': 'opentimestamps',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/opentimestamps',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2550462?'}},
#  {'id': '11658711726',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 29731392,
#    'login': 'lburack',
#    'display_login': 'lburack',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lburack',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29731392?'},
#   'repo': {'id': 234414712,
#    'name': 'NCIOCPL/glossary-app',
#    'url': 'https://api.github.com/repos/NCIOCPL/glossary-app'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/NCIOCPL/glossary-app/issues/91',
#     'repository_url': 'https://api.github.com/repos/NCIOCPL/glossary-app',
#     'labels_url': 'https://api.github.com/repos/NCIOCPL/glossary-app/issues/91/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/NCIOCPL/glossary-app/issues/91/comments',
#     'events_url': 'https://api.github.com/repos/NCIOCPL/glossary-app/issues/91/events',
#     'html_url': 'https://github.com/NCIOCPL/glossary-app/pull/91',
#     'id': 573742053,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgyMTk0NDI0',
#     'number': 91,
#     'title': '(#43) Added SearchBox to term page',
#     'user': {'login': 'seyilonge-nci',
#      'id': 58226882,
#      'node_id': 'MDQ6VXNlcjU4MjI2ODgy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/58226882?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/seyilonge-nci',
#      'html_url': 'https://github.com/seyilonge-nci',
#      'followers_url': 'https://api.github.com/users/seyilonge-nci/followers',
#      'following_url': 'https://api.github.com/users/seyilonge-nci/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/seyilonge-nci/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/seyilonge-nci/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/seyilonge-nci/subscriptions',
#      'organizations_url': 'https://api.github.com/users/seyilonge-nci/orgs',
#      'repos_url': 'https://api.github.com/users/seyilonge-nci/repos',
#      'events_url': 'https://api.github.com/users/seyilonge-nci/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/seyilonge-nci/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1875665684,
#       'node_id': 'MDU6TGFiZWwxODc1NjY1Njg0',
#       'url': 'https://api.github.com/repos/NCIOCPL/glossary-app/labels/Needs%20UX%20Review',
#       'name': 'Needs UX Review',
#       'color': '0052cc',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
# ...
#   'type': 'PushEvent',
#   'actor': {'id': 50559108,
#    'login': 'tomkotlar',
#    'display_login': 'tomkotlar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tomkotlar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50559108?'},
#   'repo': {'id': 230095356,
#    'name': 'tomkotlar/e_commerce',
#    'url': 'https://api.github.com/repos/tomkotlar/e_commerce'},
#   'payload': {'push_id': 4708104152,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '38b3e95ace613bf45d9421d595d7d09c65ba36b7',
#    'before': '5d24efd4ef10b635f05d276e74fa91bd34e11052',
#    'commits': [{'sha': '38b3e95ace613bf45d9421d595d7d09c65ba36b7',
#      'author': {'email': 't.kotlar@yahoo.com', 'name': 'tomkotlar'},
#      'message': 'adding higher order spinner component',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tomkotlar/e_commerce/commits/38b3e95ace613bf45d9421d595d7d09c65ba36b7'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711699',
#   'type': 'PushEvent',
#   'actor': {'id': 13084089,
#    'login': 'Earthcomputer',
#    'display_login': 'Earthcomputer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Earthcomputer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13084089?'},
#   'repo': {'id': 240984777,
#    'name': 'Earthcomputer/MinecraftDev',
#    'url': 'https://api.github.com/repos/Earthcomputer/MinecraftDev'},
#   'payload': {'push_id': 4708104155,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev_new',
#    'head': '284b1dea274d3aba7fea7fe54b12a34dd6190033',
#    'before': 'bc93a913943a0b3749e18bae6812799010d3bef7',
#    'commits': [{'sha': '284b1dea274d3aba7fea7fe54b12a34dd6190033',
#      'author': {'email': 'burtonjae@hotmail.co.uk', 'name': 'Joe'},
#      'message': 'Put the mixin in the client when annotated as such in the quick fix',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Earthcomputer/MinecraftDev/commits/284b1dea274d3aba7fea7fe54b12a34dd6190033'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711685',
#   'type': 'PushEvent',
#   'actor': {'id': 44846654,
#    'login': 'sandrafogg',
#    'display_login': 'sandrafogg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sandrafogg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44846654?'},
#   'repo': {'id': 216466723,
#    'name': 'maricultura/maricultura-app',
#    'url': 'https://api.github.com/repos/maricultura/maricultura-app'},
#   'payload': {'push_id': 4708104149,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'dfada9f8f1c9412207afcd068df4092d6101aca5',
#    'before': '58da98b732d9c935d14b89453ee2b1f4deaf7c25',
#    'commits': [{'sha': 'dfada9f8f1c9412207afcd068df4092d6101aca5',
#      'author': {'email': 'sandrafogg@bren.ucsb.edu', 'name': 'Sandra Fogg'},
#      'message': 'added team pictures',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/maricultura/maricultura-app/commits/dfada9f8f1c9412207afcd068df4092d6101aca5'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z',
#   'org': {'id': 54081134,
#    'login': 'maricultura',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/maricultura',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54081134?'}},
#  {'id': '11658711696',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 53286741,
#    'login': 'Cookie-Monster-Coder',
#    'display_login': 'Cookie-Monster-Coder',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Cookie-Monster-Coder',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53286741?'},
#   'repo': {'id': 77574863,
#    'name': 'causefx/Organizr',
#    'url': 'https://api.github.com/repos/causefx/Organizr'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/causefx/Organizr/issues/1319',
#     'repository_url': 'https://api.github.com/repos/causefx/Organizr',
#     'labels_url': 'https://api.github.com/repos/causefx/Organizr/issues/1319/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/causefx/Organizr/issues/1319/comments',
#     'events_url': 'https://api.github.com/repos/causefx/Organizr/issues/1319/events',
#     'html_url': 'https://github.com/causefx/Organizr/issues/1319',
#     'id': 574250694,
#     'node_id': 'MDU6SXNzdWU1NzQyNTA2OTQ=',
#     'number': 1319,
#     'title': 'Organizr become unresponsive after opening "Tab Editor" tab',
#     'user': {'login': 'Cookie-Monster-Coder',
#      'id': 53286741,
#      'node_id': 'MDQ6VXNlcjUzMjg2NzQx',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/53286741?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Cookie-Monster-Coder',
#      'html_url': 'https://github.com/Cookie-Monster-Coder',
#      'followers_url': 'https://api.github.com/users/Cookie-Monster-Coder/followers',
#      'following_url': 'https://api.github.com/users/Cookie-Monster-Coder/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Cookie-Monster-Coder/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Cookie-Monster-Coder/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Cookie-Monster-Coder/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Cookie-Monster-Coder/orgs',
#      'repos_url': 'https://api.github.com/users/Cookie-Monster-Coder/repos',
#      'events_url': 'https://api.github.com/users/Cookie-Monster-Coder/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Cookie-Monster-Coder/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2020-03-02T21:11:51Z',
#     'updated_at': '2020-03-02T22:10:15Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': '<!-- Please Fill out as much information as possible, Thanks! -->\r\n###### Organizr Version: V 2.0.362\r\n###### Branch: Develop\r\n###### WebServer: Nginx\r\n###### Operating System: Linux hosted on server\r\n<hr>\r\n\r\n##### Problem Description:\r\n[It\'s the same issue as this 2 year old post but no solution seems to be found.](https://github.com/causefx/Organizr/issues/1009)\r\nIncreasing the pm limits don\'t seem to help. \r\nHappens only on the "Tab Editor" tab in settings.\r\nWebpage becomes unresponsive.\r\nFirefox shows a tab not responding notice (The yellow warning label).\r\nMy computer ram maxes out (Without the "Tab Editor" tab open, about 4-5 GB of ram is being used, when the tab is opened ram shoots up to 7.8 GB (Have 8 GB installed)).\r\nHappens on every browser and device.\r\n\r\nHere is my nginx config file:\r\n```\r\nerror_log /home/<USER>/.config/nginx/error.log info;\r\npid /dev/null;\r\nworker_processes auto;\r\nevents { worker_connections 4096; }\r\nhttp {\r\n        include mimes.conf; #for custom file types\r\n        default_type application/octet-stream;\r\n        access_log /home/<USER>/.config/nginx/access.log combined;\r\n\r\n        client_body_temp_path /home/<USER>/.config/nginx/tmp/client_body;\r\n        proxy_temp_path /home/<USER>/.config/nginx/tmp/proxy;\r\n        fastcgi_temp_path /home/<USER>/.config/nginx/tmp/fastcgi;\r\n        uwsgi_temp_path /home/<USER>/.config/nginx/tmp/uwsgi;\r\n        scgi_temp_path /home/<USER>/.config/nginx/tmp/scgi;\r\n\r\n        server_tokens off;\r\n        sendfile on;\r\n        tcp_nopush on;\r\n        tcp_nodelay on;\r\n        keepalive_timeout 4;\r\n\r\n        output_buffers  1 32k;\r\n        postpone_output  1460;\r\n\r\n        server {\r\n                listen <PORT> ssl; #IPv4\r\n                listen [::]:<PORT> ssl; #IPv6\r\n\t\tgzip on;\r\n\t\tgzip_vary on;\r\n\t\tgzip_min_length 1000;\r\n\t\tgzip_proxied any;\r\n\t\tgzip_types text/plain text/css text/xml application/rss+xml application/vnd.ms-fontobject text/x-component application/xml application/json text/javascript font/truetype font/opentype application/x-javascript image/svg+xml application/javascript;\r\n\t\tgzip_disable "MSIE [1-6]\\.";\r\n\r\n                root /home/<USER>/.config/nginx/webroot/Organizr;\r\n\t\tserver_name <WEBSITE>.com;\r\n\r\n\t\tlocation / {\r\n\t\t\ttry_files $uri $uri/ =404;\r\n\t\t\tindex index.php index.html index.htm index.nginx-debian.html;\r\n\t\t\tinclude /home/<USER>/.config/nginx/includes/php.conf;  #PHP Block\r\n\t\t}\r\n```\r\n\r\nHere is my php-fpm2 file:\r\n\r\n```\r\n[global]\r\ndaemonize = yes\r\nerror_log = /home/<USER>/.config/php-fpm2/error.log\r\n    \r\n[www]\r\nlisten = /home/<USER>/.config/php-fpm2/socket\r\n    \r\nlisten.owner = <USER>\r\nlisten.group = <USER>\r\nlisten.mode = 0600\r\n\r\npm = dynamic\r\npm.max_children = 200\r\npm.start_servers = 15\r\npm.min_spare_servers = 15\r\npm.max_spare_servers = 25\r\npm.max_requests = 500\r\n```\r\n\r\n<hr>\r\n\r\n##### Reproduction Steps:\r\n1. Go to the Setting page\r\n2. Open "Tab Editor" tab'},
#    'comment': {'url': 'https://api.github.com/repos/causefx/Organizr/issues/comments/593649274',
#     'html_url': 'https://github.com/causefx/Organizr/issues/1319#issuecomment-593649274',
#     'issue_url': 'https://api.github.com/repos/causefx/Organizr/issues/1319',
#     'id': 593649274,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5MzY0OTI3NA==',
#     'user': {'login': 'Cookie-Monster-Coder',
#      'id': 53286741,
#      'node_id': 'MDQ6VXNlcjUzMjg2NzQx',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/53286741?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Cookie-Monster-Coder',
#      'html_url': 'https://github.com/Cookie-Monster-Coder',
#      'followers_url': 'https://api.github.com/users/Cookie-Monster-Coder/followers',
#      'following_url': 'https://api.github.com/users/Cookie-Monster-Coder/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Cookie-Monster-Coder/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Cookie-Monster-Coder/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Cookie-Monster-Coder/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Cookie-Monster-Coder/orgs',
#      'repos_url': 'https://api.github.com/users/Cookie-Monster-Coder/repos',
#      'events_url': 'https://api.github.com/users/Cookie-Monster-Coder/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Cookie-Monster-Coder/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-03-02T22:10:15Z',
#     'updated_at': '2020-03-02T22:10:15Z',
#     'author_association': 'NONE',
#     'body': "> \r\n> \r\n> Thanks - if you are on discord you can PM there or just click the support icon inside organizr on bottom left\r\n\r\nSorry it took long. Can I PM you on reddit? Discord won't let me login without putting in my cell phone number."}},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711690',
#   'type': 'CreateEvent',
#   'actor': {'id': 7718628,
#    'login': 'artsworks',
#    'display_login': 'artsworks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/artsworks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7718628?'},
#   'repo': {'id': 244486276,
#    'name': 'artsworks/dummyapi',
#    'url': 'https://api.github.com/repos/artsworks/dummyapi'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'NodeJS based API',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711686',
#   'type': 'CreateEvent',
#   'actor': {'id': 29492720,
#    'login': 'SaulEnriqueMR',
#    'display_login': 'SaulEnriqueMR',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SaulEnriqueMR',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29492720?'},
#   'repo': {'id': 244486275,
#    'name': 'SaulEnriqueMR/CuestionarioControlDeVersiones',
#    'url': 'https://api.github.com/repos/SaulEnriqueMR/CuestionarioControlDeVersiones'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Repositorio para que suban las preguntas en formato Markdown del cuestionario sobre Control de Versiones',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711677',
#   'type': 'PushEvent',
#   'actor': {'id': 16889164,
#    'login': 'Olek410',
#    'display_login': 'Olek410',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Olek410',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16889164?'},
#   'repo': {'id': 216658631,
#    'name': 'Olek410/Screentime',
#    'url': 'https://api.github.com/repos/Olek410/Screentime'},
#   'payload': {'push_id': 4708104136,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8a8f3891ddfa834300e9a59dbf3859fc6c19d70b',
#    'before': '933e40319c5f64aaf1a1bd321f97b395ccec06ac',
#    'commits': [{'sha': '8a8f3891ddfa834300e9a59dbf3859fc6c19d70b',
#      'author': {'email': 'olek5622@gmail.com', 'name': 'Olivier B'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Olek410/Screentime/commits/8a8f3891ddfa834300e9a59dbf3859fc6c19d70b'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:16Z'},
#  {'id': '11658711664',
#   'type': 'PushEvent',
#   'actor': {'id': 1214134,
#    'login': 'Hellowlol',
#    'display_login': 'Hellowlol',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hellowlol',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1214134?'},
#   'repo': {'id': 201805130,
#    'name': 'custom-components/nordpool',
#    'url': 'https://api.github.com/repos/custom-components/nordpool'},
#   'payload': {'push_id': 4708104140,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '688915c74582a53707618439343561f4b56b2f26',
#    'before': '95d9b043821d516c6a3f5a4f5e052a8d86cc9d45',
#    'commits': [{'sha': '7b04fb6218d4218dc37d6b88be367a80e9d17b59',
#      'author': {'email': 'jtfidje@gmail.com', 'name': 'Jahn Thomas Fidje'},
#      'message': 'Fix: Add correct decimal delimiter. Closes #22',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/custom-components/nordpool/commits/7b04fb6218d4218dc37d6b88be367a80e9d17b59'},
#     {'sha': '688915c74582a53707618439343561f4b56b2f26',
#      'author': {'email': 'Hellowlol@users.noreply.github.com',
#       'name': 'Steffen Fredriksen'},
#      'message': 'Merge pull request #23 from jtfidje/fix/issue-22\n\nFix: Add correct decimal delimiter. Closes #22',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/custom-components/nordpool/commits/688915c74582a53707618439343561f4b56b2f26'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:15Z',
#   'org': {'id': 40870121,
#    'login': 'custom-components',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/custom-components',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40870121?'}},
#  {'id': '11658711663',
#   'type': 'PushEvent',
#   'actor': {'id': 25534725,
#    'login': 'Faierbel',
#    'display_login': 'Faierbel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Faierbel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25534725?'},
#   'repo': {'id': 226825300,
#    'name': 'sthakrk/wulkanowy',
#    'url': 'https://api.github.com/repos/sthakrk/wulkanowy'},
#   'payload': {'push_id': 4708104141,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/patch-7',
#    'head': '1e2a382ff837f8228c46c9a69aa630f3cca89605',
#    'before': 'ab99ecdc9cf330a41f366e2bad4520d6419f091e',
#    'commits': [{'sha': '1e2a382ff837f8228c46c9a69aa630f3cca89605',
#      'author': {'email': 'rafal.borcz@goodylabs.com', 'name': 'Rafał Borcz'},
#      'message': 'Change package name',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sthakrk/wulkanowy/commits/1e2a382ff837f8228c46c9a69aa630f3cca89605'}]},
#   'public': True,
#   'created_at': '2020-03-02T22:10:15Z'}]

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection.
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception.
# - A Timeout exception will be raised if a request times out.
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# ## Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).
#
# (Cue Lindsey showing you how to use Postman with the [Dark Sky API](https://darksky.net/dev))

# %% [markdown]
# **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call.

# %%
# Option 1: use a json file saved to some other folder outside your Git repo

# Need to import json to do this
import json

# Define a function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/lberlin/secrets/api.json")

# Setting the first (and only) value as a variable
ds_key_1 = list(api_keys.values())[0]

# %%
# Option 2: use a python file that's been added to your .gitignore

# I've saved a file called keys.py in this repo, and have saved my api key as
# ds_api_key = "[key]"
from keys import ds_api_key

ds_key_2 = ds_api_key

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but be sure to clear the output of that cell or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %%
hou_lat = "29.7604"
hou_long = "-95.3698"

# %%
url = f"https://api.darksky.net/forecast/{ds_key_1}/{hou_lat},{hou_long}"

# %%
# url = "https://api.darksky.net/forecast/{}/{},{}".format(ds_key, hou_lat, hou_long)

# %%
ds_r = requests.get(url)

# %%
ds_r.json()["currently"]
# Out:
# {'time': 1583188418,
#  'summary': 'Overcast',
#  'icon': 'cloudy',
#  'nearestStormDistance': 80,
#  'nearestStormBearing': 14,
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'temperature': 75.25,
#  'apparentTemperature': 75.85,
#  'dewPoint': 65.5,
#  'humidity': 0.72,
#  'pressure': 1008.7,
#  'windSpeed': 10.5,
#  'windGust': 16.35,
#  'windBearing': 176,
#  'cloudCover': 0.99,
#  'uvIndex': 1,
#  'visibility': 10,
#  'ozone': 276.1}

# %%
berlin_url = f"https://api.darksky.net/forecast/{ds_key_2}/52.5200,13.4050,2011-11-05T20:00:00?exclude=currently,hourly,flags"

# %%
ds_berlin_r = requests.get(berlin_url)

# %%
ds_berlin_r.json()
# Out:
# {'latitude': 52.52,
#  'longitude': 13.405,
#  'timezone': 'Europe/Berlin',
#  'daily': {'data': [{'time': 1320447600,
#     'summary': 'Foggy in the morning and overnight.',
#     'sunriseTime': 1320473460,
#     'sunsetTime': 1320507120,
#     'moonPhase': 0.35,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0007,
#     'precipIntensityMaxTime': 1320483780,
#     'precipProbability': 0.09,
#     'temperatureHigh': 53.05,
#     'temperatureHighTime': 1320499980,
#     'temperatureLow': 41.72,
#     'temperatureLowTime': 1320550080,
#     'apparentTemperatureHigh': 52.55,
#     'apparentTemperatureHighTime': 1320499980,
#     'apparentTemperatureLow': 39.31,
#     'apparentTemperatureLowTime': 1320551880,
#     'dewPoint': 42.28,
#     'humidity': 0.87,
#     'windSpeed': 7.77,
#     'windGust': 12.1,
#     'windGustTime': 1320505680,
#     'windBearing': 69,
#     'uvIndex': 0,
#     'uvIndexTime': 1320480000,
#     'visibility': 4.216,
#     'temperatureMin': 39.99,
#     'temperatureMinTime': 1320475200,
#     'temperatureMax': 53.05,
#     'temperatureMaxTime': 1320499980,
#     'apparentTemperatureMin': 35.18,
#     'apparentTemperatureMinTime': 1320462540,
#     'apparentTemperatureMax': 52.55,
#     'apparentTemperatureMaxTime': 1320499980}]},
#  'offset': 1}

# %%
import pandas as pd

# %%
df_test = pd.DataFrame.from_dict(ds_berlin_r.json())

# %%
df_test
# Out:
#       latitude  longitude       timezone  \
# data     52.52     13.405  Europe/Berlin
#
#                                                   daily  offset
# data  [{'time': 1320447600, 'summary': 'Foggy in the...       1

# %% [markdown]
# ## Extra credit - Further Practice
#
# TO DO AFTER YOUR MODULE 1 PROJECT! Don't worry about doing this kind of thing now - go use a movie API rather than trying this!
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
